# %% [markdown]
# # Turing Machine and Deep Learning
#
# ## Assignment 4 -- Neural Networks
#
# This notebook is meant for you to review and reflect on the content of Lecture 4, which was mainly about neural networks. In particular, we'll focus on aspects that were only briefly mentioned in class in order for you to get a better understanding of it.
#
# ### Handing in your Assignment
#
# Git is an invaluable resource to researchers and developers, and thus for this course, all course material will be (additionally) shared on GitHub. Though there is a tiny bit of a learning curve, this is worth the effort. To hand in your assignment (applicable to all weeks):
#
# 1. Create a folder called "Week 4" and copy this notebook and any other files or data that may be needed.
# 2. Finish the notebook and commit and push regularly. Your final commit before the deadline will be graded.

# %%
# load common libraries
import numpy as np                 # maths
import matplotlib.pyplot as plt    # plotting
import pandas as pd                # data manipulation
from tqdm import tqdm              # loading bar
from time import perf_counter      # timer
import tensorflow as tf            # NNs and associated
from tensorflow import keras 
from tensorflow.keras import layers, models # NNs and associated

# %% [markdown]
# # Q1 CNNs
#
# In the lecture, we saw some code that implemented MLPs and CNNs for the task of image classification on CIFAR10. However, we skipped over some details of what CNNs actually do.
#
# A CNN works by automatically learning and extracting meaningful patterns, features, and hierarchies from the input data in the following way:
#
# 1. **Convolution**: A CNN applies (multiple) small filters (kernels) to an input image, performing element-wise multiplications and sums to extract features like edges, corners, and textures. We also did this computation in person during class. These kernels may be a matrix (what we saw in the lecture), or even a stack of matrices (e.g. for RGB images). I'd recommend watching this [3Blue1Brown video](https://www.youtube.com/watch?v=KuXjwB4LzSA&pp=ygUTY29udm9sdXRpb25zIGluIGNubg%3D%3D) and this [DeepLearning.AI](https://www.youtube.com/watch?v=KTB_OFoAQcc) video for reference.
# 2. **Non-linearity**: Non-linear activation functions (e.g., ReLU) are applied to introduce complexity and allows the capture of more abstract representations.
# 3. **Pooling**: Pooling operations are used to downsample the spatial dimensions of feature maps while preserving the most important information. In both cases, a pooling window or filter moves across the input feature map, and a single value is selected or computed within the window based on the pooling operation. Pooling helps reduce the computational complexity of the network and introduces some translation invariance. There are a few types of pooling, but most commonly used are max-pooling and average-pooling.
# 4. **Hierarchy**: Convolution and pooling operations are repeated to create a hierarchy of feature extraction layers, learning more complex and high-level features.
# 5. **Fully Connected Layers**: Flattened features are passed through fully connected layers, similar to a traditional MLP, for classification or regression.
# 6. **Training**: Parameters are adjusted using backpropagation and optimization algorithms to minimize the difference between predictions and true labels.
#
# By leveraging convolution, non-linearity, and hierarchical feature extraction, CNNs can automatically learn and recognize intricate patterns and structures in visual data, making them well-suited for tasks like image classification and object detection.
#
# You can think of the convolution operation with a kernel over an image as outputting a new modified image, called a feature map. When applying convolutions over feature maps, the size of the output feature map (in each dimension) can be computed by:
#
# $$o = \frac{i - k + 2 p}{s}+1$$
#
# where the hyperparameters of the convolution are:
# - $i$: input_size is the size (height or width) of the input feature map.
# - $k$: kernel_size is the size (height or width) of the convolutional kernel/filter.
# - $p$: padding is the number of pixels added to each side of the input feature map (if applicable) (default 0)
# - $s$: stride is the step size or the number of pixels the kernel moves at each step (default 1)
#
# The output size of a pooling operation can also be defined as:
# $$o = \frac{i - p}{s} + 1$$
#
# **Q1.1** Thus, starting with a 28x28 pixel image (e.g. MNIST), write a series of kernel sizes to use in convolutions (optionally including a pooling operation if you want to try it out, and optionally padding and stride) in order to get it down to an image size of 6x6. There are several correct answers possible here.

# %% [markdown]
# Convolution with a 5x5 kernel, no padding, and stride of 1 (output size: 24x24).

# %% [markdown]
# **Q1.2** Now, let's try out your strategy in code. Implement the convolutions you defined above to perform classification over MNIST digits. Note that most of the code is written for you, but be mindful of the steps that are written. Note that you need to choose the number of kernals as well as the size at each layer. The input shape of your next layer is the output shape you computed above and the number of kernels you chose for the previous layer ``input_shape=(w,h,k)``.

# %%
# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# Preprocess the data
x_train = x_train.reshape(-1, 28, 28, 1).astype('float32') / 255.0
x_test = x_test.reshape(-1, 28, 28, 1).astype('float32') / 255.0

# Convert the labels to one-hot encoding
y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

x_train.shape
# Out:
# (60000, 28, 28, 1)

# %%
# TODO: Complete this cell

model = models.Sequential([
    keras.layers.Conv2D(32, (5, 5), activation='relu', input_shape=(28, 28, 1)),
    keras.layers.Flatten(),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dense(10, activation='softmax')
])


# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model: choose batch size and number of epochs
history = model.fit(x_train, y_train, batch_size=128, epochs=10, validation_split=0.2)

# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# /Applications/anaconda3/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:99: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 42s 104ms/step - accuracy: 0.8909 - loss: 0.3505 - val_accuracy: 0.9811 - val_loss: 0.0655
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 39s 104ms/step - accuracy: 0.9862 - loss: 0.0476 - val_accuracy: 0.9830 - val_loss: 0.0570
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 34s 91ms/step - accuracy: 0.9921 - loss: 0.0257 - val_accuracy: 0.9858 - val_loss: 0.0515
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 36s 95ms/step - accuracy: 0.9960 - loss: 0.0139 - val_accuracy: 0.9816 - val_loss: 0.0646
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 37s 99ms/step - accuracy: 0.9975 - loss: 0.0086 - val_accuracy: 0.9852 - val_loss: 0.0595
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 34s 92ms/step - accuracy: 0.9983 - loss: 0.0058 - val_accuracy: 0.9840 - val_loss: 0.0681
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 35s 92ms/step - accuracy: 0.9980 - loss: 0.0060 - val_accuracy: 0.9833 - val_loss: 0.0706
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 35s 93ms/step - accuracy: 0.9986 - loss: 0.0049 - val_accuracy: 0.9839 - val_loss: 0.0676
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 48s 128ms/step - accuracy: 0.9977 - loss: 0.0063 - val_accuracy: 0.9843 - val_loss: 0.0760
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 50s 131ms/step - accuracy: 0.9982 - loss: 0.0058 - val_accuracy: 0.9867 - val_loss: 0.0714
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - accuracy: 0.9843 - loss: 0.0708
# Test accuracy: 0.9873999953269958

# %% [markdown]
# **Q1.3** Plot the train and validation losses and and accuracies. Do not forget to add labels What can you say about the model over/underfitting? Would you continue training it, or stop earlier? Why?

# %% [markdown]
# For the training the model, I would stop it around 4 epochs because training loss is minimized well and accuracy is high for both training and testing score.

# %%
# Plot losses
plt.plot(history.history["loss"], label='Training Loss')
plt.plot(history.history["val_loss"], label='Validation Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.grid()
plt.legend()
plt.title('Training and Validation Losses')
plt.show()

# Plot accuracies
plt.plot(history.history["accuracy"], label='Training Accuracy')
plt.plot(history.history["val_accuracy"], label='Validation Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.grid()
plt.legend()
plt.title('Training and Validation Accuracies')
plt.show()

# %% [markdown]
# # Q2 RNNs
#
# An RNN (Recurrent Neural Network) is a type of artificial neural network that is particularly effective in processing sequential data. Unlike feedforward neural networks, which process inputs independently, RNNs have connections that allow information to flow in cycles. This cyclic connectivity enables them to capture temporal dependencies and learn patterns over time. You can find more in these [neural network lecture notes (Jaeger 2023, chapter 4)](https://www.ai.rug.nl/minds/uploads/LN_NN_RUG.pdf). Here is an overview of how RNNs work:
#
# - **Recurrent Connections**: RNNs have recurrent connections that allow information to be passed from one step to the next in a sequence. At each time step, the RNN takes an input and combines it with the information from the previous step. This feedback loop enables the network to have memory and make predictions based on the context of past inputs.
#
# - **Hidden State**: RNNs maintain a hidden state vector that serves as a memory of the network. The hidden state is updated at each time step and contains information about the previous inputs in the sequence. It captures the network's understanding of the sequence up to that point and is used to influence the processing of future inputs.
#
# - **Sequence Processing**: RNNs process sequences by iterating through each element one at a time. As the network receives an input at each time step, it updates its hidden state based on the input and the previous hidden state. The updated hidden state is then used to make predictions or generate outputs.
#
# - **Long Short-Term Memory (LSTM) and Gated Recurrent Units (GRU)**: LSTMs and GRUs are popular types of RNN architectures that address the vanishing gradient problem and capture long-term dependencies more effectively. These architectures introduce specialized memory cells and gating mechanisms that allow the network to selectively update and forget information.
#
# - **Training**: RNNs are typically trained using the backpropagation through time (BPTT) algorithm, which extends backpropagation to handle sequences. The goal is to minimize the difference between the predicted outputs and the true targets by adjusting the network's parameters through gradient descent optimization.
#
# - **Applications**: RNNs are well-suited for tasks involving sequential data, such as natural language processing, speech recognition, machine translation, time series analysis, and sentiment analysis. They can effectively model dependencies and capture context in these domains.
#
# By leveraging recurrent connections and hidden state information, RNNs excel at processing and understanding sequential data. They are powerful tools for tasks that require temporal modeling and have made significant contributions to the field of deep learning.
#
# Here, we'll use LSTMs to regress on the [Air Passengers](https://www.kaggle.com/datasets/chirag19/air-passengers) dataset, providing monthly totals of a US airline passengers from 1949 to 1960.

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error

# Load the Air Passengers dataset
data = pd.read_csv("/Users/sameeksha/Desktop/ML/W4/AirPassengers - 2024.csv")
time_series = data['#Passengers'].values.astype(float)

# preprocess, use a scaler to scale the features to 0 and 1
time_series = np.array(time_series).reshape(-1,1)
scaler = MinMaxScaler(feature_range=(0, 1))
time_series = scaler.fit_transform(time_series)

# Split the data into training and testing sets
train_data = time_series[:120]  # First 120 months for training
test_data = time_series[120:]   # Last 24 months for testing

# Function to create input sequences
# Goal: Predict the (n+1)th point given n points
def create_sequences(data, seq_length):
    X = []
    y = []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length])
    return np.array(X), np.array(y)

# Define sequence length and create input sequences
sequence_length = 6
X_train, y_train = create_sequences(train_data, sequence_length)
X_test, y_test = create_sequences(test_data, sequence_length)

# Reshape the input data to be 3D (batch_size, sequence_length, num_features)
# Standard practice!
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %% [markdown]
# **Q2.1** Finish the following cell

# %%
from tensorflow import keras

# Define the LSTM model
model = keras.Sequential([
    keras.layers.LSTM(units=50, input_shape=(sequence_length, 1)),
    keras.layers.Dense(units=1)  # Regression task, so only one output neuron
])

model.compile(loss='mean_squared_error', optimizer='adam')

history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)
# Out:
# /Applications/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 360ms/step - loss: 0.0813 - val_loss: 0.2789
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0554 - val_loss: 0.2130
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0382 - val_loss: 0.1574
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0308 - val_loss: 0.1110
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0191 - val_loss: 0.0745
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0131 - val_loss: 0.0483
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0090 - val_loss: 0.0330
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0102 - val_loss: 0.0258
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0109 - val_loss: 0.0244
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0115 - val_loss: 0.0256
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0099 - val_loss: 0.0292
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0086 - val_loss: 0.0336
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0078 - val_loss: 0.0373
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0080 - val_loss: 0.0394
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0079 - val_loss: 0.0393
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0084 - val_loss: 0.0374
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0078 - val_loss: 0.0348
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0072 - val_loss: 0.0315
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0071 - val_loss: 0.0288
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0062 - val_loss: 0.0268
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0065 - val_loss: 0.0254
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0064 - val_loss: 0.0247
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0063 - val_loss: 0.0247
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0069 - val_loss: 0.0248
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0064 - val_loss: 0.0249
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0063 - val_loss: 0.0250
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0060 - val_loss: 0.0247
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - loss: 0.0055 - val_loss: 0.0242
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0059 - val_loss: 0.0238
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0057 - val_loss: 0.0234
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0060 - val_loss: 0.0231
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0054 - val_loss: 0.0230
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0054 - val_loss: 0.0231
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0063 - val_loss: 0.0231
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0059 - val_loss: 0.0231
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0059 - val_loss: 0.0230
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0057 - val_loss: 0.0230
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0055 - val_loss: 0.0230
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0051 - val_loss: 0.0227
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0058 - val_loss: 0.0225
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0056 - val_loss: 0.0224
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0050 - val_loss: 0.0224
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0058 - val_loss: 0.0224
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0053 - val_loss: 0.0224
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0057 - val_loss: 0.0223
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0057 - val_loss: 0.0221
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0053 - val_loss: 0.0221
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0054 - val_loss: 0.0220
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0051 - val_loss: 0.0219
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0051 - val_loss: 0.0218
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0053 - val_loss: 0.0216
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0053 - val_loss: 0.0215
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 0.0052 - val_loss: 0.0215
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0052 - val_loss: 0.0216
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0048 - val_loss: 0.0216
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0053 - val_loss: 0.0213
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0054 - val_loss: 0.0212
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0052 - val_loss: 0.0213
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0047 - val_loss: 0.0212
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0054 - val_loss: 0.0210
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0051 - val_loss: 0.0209
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0052 - val_loss: 0.0208
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0057 - val_loss: 0.0207
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 149ms/step - loss: 0.0052 - val_loss: 0.0208
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0049 - val_loss: 0.0209
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0051 - val_loss: 0.0207
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0054 - val_loss: 0.0206
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0051 - val_loss: 0.0205
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0053 - val_loss: 0.0204
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0057 - val_loss: 0.0204
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0054 - val_loss: 0.0202
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0051 - val_loss: 0.0202
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0056 - val_loss: 0.0201
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0049 - val_loss: 0.0200
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0044 - val_loss: 0.0198
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0052 - val_loss: 0.0198
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0051 - val_loss: 0.0197
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0053 - val_loss: 0.0196
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 189ms/step - loss: 0.0048 - val_loss: 0.0195
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 616ms/step - loss: 0.0046 - val_loss: 0.0197
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0052 - val_loss: 0.0197
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0055 - val_loss: 0.0197
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - loss: 0.0048 - val_loss: 0.0193
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0053 - val_loss: 0.0191
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0048 - val_loss: 0.0190
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0050 - val_loss: 0.0191
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0048 - val_loss: 0.0191
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0048 - val_loss: 0.0190
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0049 - val_loss: 0.0189
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0050 - val_loss: 0.0188
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0046 - val_loss: 0.0188
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0041 - val_loss: 0.0188
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0048 - val_loss: 0.0185
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0050 - val_loss: 0.0182
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0046 - val_loss: 0.0184
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0053 - val_loss: 0.0183
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0049 - val_loss: 0.0184
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0050 - val_loss: 0.0182
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0047 - val_loss: 0.0182
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.0043 - val_loss: 0.0182

# %% [markdown]
# **Q2.2** Plot the train and validation losses and and accuracies. Do not forget to add labels What can you say about the model over/underfitting? Would you continue training it, or stop earlier? Why?

# %% [markdown]
# I would stop is around 20 epochs because after that the model is not getting better at an increasing rate.

# %%
import matplotlib.pyplot as plt

# Plot losses
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Losses')
plt.legend()
plt.show()

# %% [markdown]
# Now, we can make predictions on our test set and evaluate it!
#
# **Q2.3** Finish the following cell

# %%
# Predict on the test set
# make predictions
train_preds = model.predict(X_train)
test_preds = model.predict(X_test)

# invert predictions to make it original scale
train_preds = scaler.inverse_transform(train_preds)
y_train = scaler.inverse_transform(y_train)
test_preds = scaler.inverse_transform(test_preds)
y_test = scaler.inverse_transform(y_test)

# plotting code adapted from https://www.kaggle.com/code/singhalamogh/lstm-regression-on-time-series-data
# shift train predictions for plotting
trainPredictPlot = np.empty_like(data)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[sequence_length:len(train_preds) + sequence_length, :] = train_preds

# shift test true data for plotting
testTruePlot = np.empty_like(data)
testTruePlot[:, :] = np.nan
testTruePlot[len(train_preds)+sequence_length:len(data), :] = scaler.inverse_transform(test_data)

# shift test predictions for plotting
testPredictPlot = np.empty_like(data)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(train_preds)+2*sequence_length:len(data), :] = test_preds

# plot baseline and predictions
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
plt.plot(scaler.inverse_transform(train_data), color=colors[0], label="Train data")
plt.plot(testTruePlot[:,0], color=colors[1], label="Test data")
plt.plot(trainPredictPlot[:,0], color=colors[0], linestyle="--", label="Predictions based on train data")
plt.plot(testPredictPlot[:,0], color=colors[1], linestyle="--", label="Predictions based on test data")
plt.legend()
plt.show()

# calculate root mean squared error
train_score = mean_squared_error(y_train, train_preds)
print('Train Score: %.2f (MSE)' % (train_score))
test_score = mean_squared_error(y_test, test_preds)
print('Test Score: %.2f (MSE)' % (test_score))
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Train Score: 1963.75 (MSE)
# Test Score: 8159.02 (MSE)

# %% [markdown]
# **Q2.4** Does the model do well? Write three ideas on how you would make it better. Implement at least one of these ideas and rerun your code, and report your results.

# %% [markdown]
# Train Score - 1963.75 (MSE), indicates on average, the model's predictions on the training set are off by approximately 1963.75 passengers squared and the Test Score - 8159.02 (MSE) is higher than training score which might point to overfitting of the model.
#
# Reducing the Dropout Rate: decrease the randomness into the model and increase its reliance on specific features or patterns in the data.
#
# Add Regularization: Regularization techniques like L1 or L2 regularization can be used to penalize large parameter values.
#
# Use a Smaller Model: Using a smaller model architecture with fewer hidden layers to make the model less complex

# %%
# Build the LSTM model with increased dropout rate
model = keras.Sequential([
    keras.layers.LSTM(50, input_shape=(sequence_length, 1), dropout=0.0001),
    keras.layers.Dense(1)
])

# Compile and train the model
model.compile(loss='mean_squared_error', optimizer='adam')
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2)

# Predict on the test set
train_preds = model.predict(X_train)
test_preds = model.predict(X_test)

# Invert predictions to the original scale
train_preds = scaler.inverse_transform(train_preds)
y_train = scaler.inverse_transform(y_train)
test_preds = scaler.inverse_transform(test_preds)
y_test = scaler.inverse_transform(y_test)

# Calculate root mean squared error
train_score = mean_squared_error(y_train, train_preds)
test_score = mean_squared_error(y_test, test_preds)
print('Train Score: %.2f (MSE)' % (train_score))
print('Test Score: %.2f (MSE)' % (test_score))
# Out:
# /Applications/anaconda3/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 0.0445 - val_loss: 0.1403
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0246 - val_loss: 0.1012
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0188 - val_loss: 0.0667
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0097 - val_loss: 0.0398
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0076 - val_loss: 0.0233
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0063 - val_loss: 0.0180
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0087 - val_loss: 0.0174
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0083 - val_loss: 0.0182
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0077 - val_loss: 0.0211
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0063 - val_loss: 0.0249
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0051 - val_loss: 0.0281
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0061 - val_loss: 0.0296
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0059 - val_loss: 0.0289
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0062 - val_loss: 0.0265
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0063 - val_loss: 0.0236
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0047 - val_loss: 0.0216
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0050 - val_loss: 0.0202
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0049 - val_loss: 0.0197
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0048 - val_loss: 0.0197
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0053 - val_loss: 0.0199
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0050 - val_loss: 0.0204
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0049 - val_loss: 0.0207
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0053 - val_loss: 0.0206
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0045 - val_loss: 0.0200
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0052 - val_loss: 0.0197
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0050 - val_loss: 0.0194
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0053 - val_loss: 0.0193
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0049 - val_loss: 0.0195
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0052 - val_loss: 0.0195
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0051 - val_loss: 0.0195
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0044 - val_loss: 0.0194
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0048 - val_loss: 0.0193
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0046 - val_loss: 0.0192
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0044 - val_loss: 0.0193
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0049 - val_loss: 0.0191
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0044 - val_loss: 0.0190
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0049 - val_loss: 0.0189
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0045 - val_loss: 0.0189
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0048 - val_loss: 0.0191
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0051 - val_loss: 0.0189
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0046 - val_loss: 0.0187
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0052 - val_loss: 0.0188
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0046 - val_loss: 0.0187
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0046 - val_loss: 0.0186
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0052 - val_loss: 0.0185
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0047 - val_loss: 0.0187
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0042 - val_loss: 0.0185
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0045 - val_loss: 0.0183
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0048 - val_loss: 0.0181
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0048 - val_loss: 0.0180
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0050 - val_loss: 0.0180
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0049 - val_loss: 0.0182
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0046 - val_loss: 0.0184
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0044 - val_loss: 0.0181
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0051 - val_loss: 0.0178
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0047 - val_loss: 0.0177
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0043 - val_loss: 0.0178
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0042 - val_loss: 0.0177
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0047 - val_loss: 0.0178
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0051 - val_loss: 0.0176
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0050 - val_loss: 0.0176
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0048 - val_loss: 0.0176
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0046 - val_loss: 0.0177
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0043 - val_loss: 0.0176
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0045 - val_loss: 0.0174
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0046 - val_loss: 0.0171
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0047 - val_loss: 0.0170
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0049 - val_loss: 0.0170
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0046 - val_loss: 0.0173
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0039 - val_loss: 0.0174
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0045 - val_loss: 0.0172
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0047 - val_loss: 0.0168
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0037 - val_loss: 0.0167
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0042 - val_loss: 0.0168
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0042 - val_loss: 0.0168
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - val_loss: 0.0169
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0041 - val_loss: 0.0169
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0036 - val_loss: 0.0167
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0039 - val_loss: 0.0166
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0045 - val_loss: 0.0163
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0041 - val_loss: 0.0162
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0045 - val_loss: 0.0164
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0042 - val_loss: 0.0167
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0041 - val_loss: 0.0165
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0040 - val_loss: 0.0161
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0044 - val_loss: 0.0159
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0040 - val_loss: 0.0160
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0042 - val_loss: 0.0160
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0043 - val_loss: 0.0162
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0043 - val_loss: 0.0161
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0039 - val_loss: 0.0158
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0040 - val_loss: 0.0158
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0040 - val_loss: 0.0159
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0041 - val_loss: 0.0156
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0040 - val_loss: 0.0155
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0040 - val_loss: 0.0157
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0037 - val_loss: 0.0158
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0041 - val_loss: 0.0156
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0037 - val_loss: 0.0154
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0038 - val_loss: 0.0150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Train Score: 1660.87 (MSE)
# Test Score: 6614.70 (MSE)

# %% [markdown]
# # Q3 NLPs
#
# The guest lecturer of week 5 will talk about natural language processing (NLPs). To prepare for this please watch the following videos and per video tell us one thing you learned.
#
# Videos
# Intro (5 minutes); https://www.youtube.com/watch?v=CMrHM8a3hqw
#
# Transform & Bert (10 minutes); https://www.youtube.com/watch?v=SZorAJ4I-sA
#
# Optional; Transform (13 minutes) (more in depth); https://www.youtube.com/watch?v=TQQlZhbC5ps

# %% [markdown]
# Intro - NLP gives machines the ability to read and write; understand human behaviour; NLP can be used in autocorrection or plagirism check
# Transform & Bert - transformer is like neural model for text; it depends on positional encoding, attention and self-attention
